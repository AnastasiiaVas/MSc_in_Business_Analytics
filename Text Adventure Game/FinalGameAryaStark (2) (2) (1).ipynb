# %% [markdown]
# ### Text Adventure Game
#
# The task is to design a text-based adventure game.
#
# My game is based on the TV Show "Game of Thrones"(actions take place in the season 5,6). The user plays for Arya Stark and has to find the House of Black and White to start training as a Faceless Man.
# The main goal is to pass all three stages and survive.
#
# ##### Rounds
# - Reach Braavos
# - Trainings to become a Faceless Man
# - Identity struggles-
# and loyalty to the Faceless Men

# %%
#importing necessary packages
from numpy import random
import pandas as pd
from sys import exit

#define INTRO stage- player will begin here
def INTRO():
    #introduction to the game
    #defining variable for user's name
    print("*"*80)
    global user_name
    user_name= input(prompt= "Hello Dear Guest, please tell me your name.- ")
    print("*"*80)
    print(f"""
    Oh, you have such a beautiful name {user_name}. But from now your name will be Arya Stark. 
    Welcome to the Text Adventure Game based on the TV Show \"Game of Thrones\" 
    (actions take place in the season 5,6).
    """)
    #asking in player wants to play or not
    user_answer= input(prompt=f"""
    Now, tell me please if you want to play(answer \"yes\" if you want to play, 
    \"no\" if you prefer not to play)- """).lower()
    #controlling the output
    while user_answer != "no" and user_answer!= "yes":
        print(F"""
        Incorrect input. Please enter yes or no.""")
        user_answer= input(prompt=f"""
        Now, tell me please if you want to play(answer \"yes\" if you want to play, 
        \"no\" if you prefer not to play)- """).lower()
    #if answer yes- we transfer player to the STAGE_1
    if user_answer== "yes":
        print(f"""
        Okay, then I will bring you up to speed a little bit.""")
        input("<Press enter to continue to the next stage>\n")
        STAGE_1()
    
    #if answer no- we finish
    elif user_answer== "no":
        print(f"""
    That's sad to hear, but is's okay, have a good day {user_name}.""")
        exit(0)


#defining FAIL functions
def FAIL():
    print(f"""
Sorry {user_name}, you have failed the mission. 
Game over.""")
    exit(0)


#defining STAGE 1
def STAGE_1():
    print("-"*50)
    #plot explanation
    print(f"""
        You are on your way to Braavos: you are aimed to find the House of Black 
        and White to start training as a Faceless Man. 
        You determined to master the skills you needs to take revenge on those who wronged your family.

        You have a hard road ahead of you. Your journey to Braavos is filled with many 
        challenges and dangers that you must overcome in order to reach final destination.""")
    print(f"""
        You are halfway there, but the lack of food is becoming a big problem. 
        To survive you have to steal food, but the city where you are staying 
        has very attentive and cruel guards - you can be caught and imprisoned.""")

    #NEW TASK- you have to steal food to survive- defining variable for this(to steal or not to steal)
    task1= input(prompt=f"""
        You must choose whether to steal food or try to survive without stealing. 
        Answer \"yes\" for stealing, and \"no\" to not stealing.""").lower()
    #input control- we need only "yes" or "no". Making loop for that.
    while task1 != "yes" and task1 != "no":
        print("""
        Input is invalid. Answer \"yes\" for stealing, and \"no\" to not stealing.""")
        task1= input(prompt= f"""
        You must choose whether to steal food or try to survive without stealing. 
        Answer \"yes\" for stealing, and \"no\" to not stealing.""").lower()
    #outcome if you decide to steal food- it will transfer player to  STEAL function(below)
    if task1 == "yes":
        print(f"""
            You stole a nice, fresh loaf of bread from the local shop...
            But...Oh no, you see the guards coming right at you. 
            Someone saw you stealing and complained.""")
        input("<Press enter to continue>")
        STEAL()
    #outcome if you decide not to steal food      
    elif task1 == "no":
        print(f"""
            It is very pleasant to realize that in this world there are still ladies of high morals. 
            But you can't continue - you're too hungry.""")
        #defining variable whether to beg for food or not to beg    
        beg= input(prompt= "Will you beg food from passers-by?(answer 'yes' or 'no')").lower()
        while beg != "yes" and beg != "no":
            print("Input is invalid. Answer 'yes' or 'no'.")
            beg= input(prompt= """
                Will you beg food from passers-by?(answer 'yes' or 'no')""").lower()
        #outcome for if you decided to beg    
        if beg== "yes":
            print(f"""
            Wise decision. 
            Several passers-by treated you with pastries and fruits - 
            now you feel a surge of strength and you can move on.""")
            input("<Press enter to continue>")
            print(f"""
            You managed to find a ship bound for Braavos. 
            Welcome to Stage 2!.""")
            input("<Press enter to continue>\n")
            STAGE_2()
        #outcome if you decided tot to beg    
        elif beg=="no":
            print(f"""
                Sometimes it's better to sacrifice your ego for a happy ending. 
                You are too arrogant and would rather starve to death than beg for food from passers-by.""")
            FAIL()

            
#defining function for task1 in the STAGE_1(if you decided to steal)
def STEAL():
    #defining variable for task1_1- where should you run(left/right/back)?
    task1_1= input(prompt= f"""
            You must navigate through the streets to avoid being caught. 
            Which direction do you want to go? (left/right/back): """).lower()
    #input controlling
    while task1_1 != "left" and task1_1 != "right" and task1_1 != "back":
        print("""
            Input is invalid. Answer left/right/forward/back.""")
        task1_1= input(prompt= f"""
            You must navigate through the streets to avoid being caught. 
            Which direction do you want to go? (left/right/back): """).lower()

    #outcomes for each decision
    #defining variale if you go left
    if task1_1== "left":
        print(f"""
            You tripped over a rock and fell.
            The guards grabbed you.""")
        FAIL()

    #defining variale if you decided to go right
    elif task1_1== "right":
        print("""
            You see an open door - you can hide there. 
            But you don't know what's waiting for you behind that door. """)
        #variable for decsicion of going inside the door or not 
        door = input(prompt=f"""
            Will you take a risk? (Answer 'yes' or 'no')""").lower()
        #input control
        while door != "yes" and door != "no":
            print("Input is invalid. Answer 'yes' or 'no'.")
            door = input(prompt=f""" 
            Will you take a risk? (Answer 'yes' or 'no')""").lower()
        #outcome if you go inside the door
        if door== "yes":
            #defining variable "probability" that we gonna need for our strategy
            probability= random.randint(1,10)
            #Here is the startegy that defines if you are lucky today or not. We have range of numbers from 1 to 10.
            #Variable "probability" gives you a random number- if the number is higher that 2- it's your lucky day and you 
            #continue to play. If the number is 2 or 1- you lost-it's not your lucky day.
            if probability > 2:
                print(f"""
                It's your lucky day. It turned out to be a local old woman's hut. 
                Now, you are hidden from the guards, fed and provided with a stable.""")
                input("<Press enter to continue>")
                print(f"""
                Enough of rest, it's time to move forward to get to Braavos.
                As it is an island city - it's not easily accessible by land. 
                You finally managed to find a ship bound for Braavos- Welcome to Stage 2!""")
                input("<Press enter to continue>\n") 
                STAGE_2()   
            else:
                print(f"""
                Unfortunately, it's a robbers haven behin this door- 
                you were sold into slavery """)
                FAIL()
        #outcome if you don't go inside the door
        elif door=="no":
            print("The guards caught you.")
            FAIL()
            
    #defining variale if you decided to go right
    elif task1_1== "back":
        print(f"""
            Congratulations! You are saved from guards...but...who is this approaching you...??
            OH NO, you ran into a gang of local robbers. They will only let you go on one condition- 
            you have to give them the coin given to you by Jaqen H'ghar. 
            Without this coin you won't gain passage to the Braavos city. """)
        #You saved from guards but faced robbers who want your coin. We define variable for your decsicion.
        coin= input(prompt= "You have to make a decision. Will you give robbers the coin? (yes/no)").lower()
        #input control
        while coin != "yes" and coin != "no":
            print("Input is invalid. Answer 'yes' or 'no'.")
            coin= input(prompt= """
                    You have to make a decision. Will you give robbers the coin?""").lower()
        #outcome for if you decided to give a coin
        if coin == "yes":
            print(f"""
                Oh...now you won't be able to reach Braavos and take revenge on those 
                who wronged your family.""")
            FAIL()
        #outcome for if you decided not to give a coin
        elif coin == "no":
            print(f"""
                    Wise decision.""")
            #you decided not to give robbers your coin- you run or fight? it's anew variable for this question
            fight= input(prompt= """
                    But now the main question- What to do next: fight or run?""").lower()
            #input control
            while fight != "fight" and fight != "run":
                print("""
                    Input is invalid. Answer 'fight' or 'run'.""")
                fight= input(prompt= """
                    But now the main question. What to do next: fight or run?""").lower()
            #outcome if you decided to fight
            if fight== "fight":
                print(f"""
                    Poor little Arya, what you hoped for - the robbers are twice your size. 
                    You were captured .. and what will happen next, one can only guess...""")
                FAIL()
            #outcome if you decided to fight
            elif fight=="run":
                print(f"""
                    Cool. You successfully escaped. 
                    You eventually stumbles upon a ship bound for Braavos and used the coin to reach Braavos.
                    Welcome to the Stage 2.""")
                input("<Press enter to continue>\n")
                STAGE_2()

#******************************************************************************
#STARTING STAGE 2
#for stage 2 and its tasks we will need dictionaries. You can see them below.
#Dictionaries for stage_2
#Define tasks options
tasks = {
'steal_item':    'You have been assigned to steal a valuable item from a wealthy merchant.',
'assassination': 'You have to win the hooded figure',
'disguise':      'You have been assigned to hypnotize someone from a rival guild and gather information.'}
#Define training options
training = {
'face_changing': 'You practice using a special potion to change your appearance.',
'combat':        'You practice various forms of combat with a hooded figure.',
'deception':     'You learn the art of deception and hypnosis in order to infiltrate and manipulate different groups or individuals.'}

#defining function for stage 2             
def STAGE_2():
    print("*"*80)
    #intro for stage 2
    print(f"""
    My congratulations. You've successfully made it to Braavos... 
    But here comes the hardest part: you have to be fully committed to your training 
    as a Faceless Man.

    You will have to complete various tasks throughout the Stage 2:
    1) Face Changing will be your first trainning
    2) Combat is the second one
    3) Deception is the last one.

    Let's get started! Good Luck!""")
    #starting stage 2 with face changing function. we call it.
    FACE_CHANGING()

#defining face chaging function
def FACE_CHANGING():
    print("*"*40)
    task = tasks["steal_item"]
    print(task)
    print("""
    To complete this task, you must use your new face-changing abilities to infiltrate 
    the merchant's mansion and steal the Valyrian Steel Dagger. """)
    
    #making loop. the player will have 3 tries.
    q= 3
    for round in range(q):
        #variable for mission time- steal during the day or at night
        mission_time = input(f"""
    Do you want to steal the Dagger during the day or at night? (day/night)
    Sometimes at night the merchant leaves home for balls and dinner, 
    but sometimes he stays home - you never know.""").lower()
        #input control
        while mission_time != "day" and mission_time != "night":
            print("Invalid input. Please enter day or night.")
            mission_time = input("""
    Do you want to steal the Dagger during the day or at night? (day/night)""").lower()
        #Here is the startegy. Variable merchant_is_not_at_home shows when mechant is not at home-
        #(it gives you "day" or "night" randomly). If the player choses time when merchant is NOT at home-
        # he wins. I he whoses opposite- he loses.
        merchant_is_not_at_home= random.choice(["night", "day"])
        #when player wins
        if merchant_is_not_at_home == mission_time:
            print("""
    You have successfully chosen mission time. Merchant is not at home.""")
            input("<Press enter to continue>\n")
            break
        #player loses
        else:
            print("""
    Oh no! The merchant is at home. Mission failed, but you are allowed to try again. 
    You have 3 tries in total.""")
        
        q -= 1
    if q == 0:
        print("You took too much tries. Game over")
        FAIL()
                
    #if you won previous task you proceed to this part
    print("*"*40)
    print(f"""
     You successfully creeped into the house. But this is only the beggining of the training. 
     Now you have to use a special potion to change your appearance.
     You drank the potion- now you can change your face.""")
    
    #making loop. the player will have 2 tries.
    w=2
    for round in range(w): 
        #imput control. we net only a/b/c answers
        try:
            face=input(prompt= f"""
        ________________________________________
        Pleace chose the face you want to put on:
        a) merchant's wife face, 
        b) merchant's son face, 
        c) merchant's best friend face""").lower()
            
        except ValueError and (spell!= a, spell!=b, spell!=c) :
            print("Incorrect input. Enter a, b, or c.")        
            face=input(prompt= f"""
         ________________________________________
         Pleace chose the face you want to put on:
         a) merchant's wife face, 
         b) merchant's son face, 
         c) merchant's best friend face""").lower()
        
        #if answer="a"- wrong answer
        if face == "a":
            print(f"""
        Bad choice. Five years ago the merchant's wife ran away from him with a young soldier. 
        If the guards see her, they will arrest her.""")
            print(" You failed, but you can try again. You have 2 tries in total.")
            input("<Press enter to continue>\n")
        
        #if answer="b"- right answer
        elif face== "b":
            print(f"""
        That was a goood move. Merchant and his son are in a really good relationship. 
        He is always welcome in the merchant's mansion.""")
            input("<Press enter to continue>\n")
            print(f"""
        Congratulations! You successfully used a special potion and stole the Valyrian Steel Dagger.
        Face changing training is completed.""")
            break
        
        #if answer="a"- wrong answer
        elif face=="c":
            print(""" 
            Merchant does not have frinds. 
            Guards arrested you.""")
            print(" You failed, but you can try again. You have 2 tries in total.")
            
        w-= 1
    #this we need to reduce amound of tries    
    if w== 0:
        print("You took too much tries. Game over")
        FAIL()
        
    COMBAT()
            
# Define the combat function- next training        
def COMBAT():
    print("""
    First trainning is completed. Now, proceed to the second training please.""")
    print("*"*40)
    task = tasks["assassination"]
    print(task)
    print("""
To complete this task, you have to win a hooded figure.
Let's see if you skilled enough to beat your competitor.
""")
    input("""
<Press enter to continue>\n""")
    
    #Strategy for combat function. Player has 100 points of health and hooded figure 75. Within each round
    #you deal damage(between 10 to 15: it's randomly generated by Python.) and nooded figure also deal damage to you(12:18).
    #With each round your healt points decrease. Loses one who lost all his health points.
    player_health = 100
    hooded_figure_health = 75

        # Define weapons
    player_weapon = {"name": "Sword", "min_damage": 10, "max_damage": 15}
    hooded_figure_weapon = {"name": "Axe", "min_damage": 12, "max_damage": 18}

    #making loop. game will continue until one of the player will reach 0 points of health
    while player_health > 0 and hooded_figure_health > 0:
        #random generation of damage
        player_damage = random.randint(player_weapon["min_damage"], player_weapon["max_damage"])
        hooded_figure_damage = random.randint(hooded_figure_weapon["min_damage"], hooded_figure_weapon["max_damage"])

        # Player attacks
        print("You deal", player_damage, "damage with", player_weapon["name"])
        hooded_figure_health -= player_damage

            # Hooded figure attacks
        print("Hooded figure deals", hooded_figure_damage, "damage with", hooded_figure_weapon["name"])
        player_health -= hooded_figure_damage
        if player_health <= 0:
            print("You defeated!")
            print("Hooded figure wins!")
            FAIL()
                
        if hooded_figure_health <= 0:
            print("""
    Hooded figure defeated!""")
            print("""
    You won!""")
            input("<Press enter to continue>")
            break

    DECEPTION()
     
#defining DECEPTION function                 
def DECEPTION():
    print("""
    Second trainning is done. You have to complete the last one.""")
    print("*"*40)
    task = tasks["disguise"]
    print(task)
   
    print(f"""
    The art of hypnosis is exterimely important for becoming a Faceless.
    In order to become a master of deception, you have do complete the hypnosis training.""")
        
    print(""" 
    You infiltrated a rival guild - now, hypnotize one of the solgiers to gather important information.
    During your trainings in the House of Black and White, you were learning spells helping to hypnotise people.""")
    input("<Press enter to continue>")
    
    #defining new variable for the spell. also controlling the input
    try:
        spell=input("""\
    ____________________________________________
    Which spell can make a person tell the truth:
    a) Veritaserum 
    b) Incarcerous 
    c) Alohomora 
    _____________________________________________""")
    
    except ValueError and (spell!= a, spell!=b, spell!=c) :
        print("Incorrect input. Enter 1, 2, or 3.")        
        spell= input("""
    Which spell can make a person tell the truth:
    a) Veritaserum 
    b) Incarcerous 
    c) Alohomora """)
      
    #outcome for each answer
    if spell == "a":
        print("""
        You are absolutely correct, Good Job!
        You used this spell and gathered all information nedeed.""")
        input("<Press enter to continue>")
        STAGE_3()
    elif spell =="b":
        print(f"""
        Welll....This spell is actually not for making people telling the truth, but for making them unconscious.
        But it could also work.
              
        You made soldier unconsious and gathered all information needed, Well done!""")
        input("<Press enter to continue>")
        STAGE_3()
    elif spell=="c":
        print("""
        Ohhh....You should have been more attentive in the hypnosis class at the House of Black and White.
        The Alohomora spell is used to unlock doors, but not to make people tell the truth.
              
        You chose the wrong spell and were caught by the guards.""")
        FAIL()

#****************************************************************************************************
#STAGE 3
#Defining function for stage 3
def STAGE_3():
    print("*"*100)
    print("""
Congratulations! You are on third stage of the game!
It was a sophisticated and long way, but you made it!""")
    print("""
Initially you appeared to be fully committed to your training as a Faceless Man. 
However, as you carried out your missions, you began to struggle with your identity 
and loyalty to the Faceless Men.""")
        
    print("""
You are not comfortable with the fact that Faceless Men kills without any remorse.
As the season progresses, you start to question the true purpose of trainings.""")
    #defining new varioble for vinal decision- stay commited to faceless or leave them
    final= input("""
Now it comes the time to question yourself:  
a) Ultimately choose to abandon trainings and reject the Faceless Men and their 
way of life in favor of reclaiming you own identity.
b) Stay committed to Faceless Men for the rest of her life.""").lower()
    #input control
    while final != "a" and final != "b":
        print("""
Incorrect input. Please enter 'a' or 'b'.""")
        final= input("""
Now it comes the time to question yourself:  
a) Ultimately choose to abandon trainings and reject the Faceless Men and their 
way of life in favor of reclaiming you own identity.
b) Stay committed to Faceless Men for the rest of her life.""").lower()
    #outcome for each answer
    #you decided to leave Faceless men
    if final== "a":
        print("""
Faceless Men won't let you go like that. They put a lot of effort to 
train you and they want you to be one of them forever.""")
        input("""<Press enter to continue>""")
        #you decided to leave Faceless men-will you kill Jaque in order to escape?
        escape= input(f"""
To successfully escape you have to kill Jaqen H'ghar, who was helping you 
throughout your path right from the beginning.
It would be a very low treason- but only this will help you to leave the 
House of Black and White.(answer 'yes' for killing, 'no' for not killing)""").lower()
        while escape != "no" and escape != "yes":
            print("""
Invalid input. Enter 'yes' or 'no'.""")
        #you decided to leave Faceless men and you kill Jaquen-result of these actions is below      
        if escape== "yes":
            print("""
Congratulations, this is the end of the Game! 
Now, you are on your way to Westeros to help your family and friends.
Good luck!""")
            exit(0)
        #you decided to leave Faceless men and didn't kill Jaquen-result of these actions is below     
        elif escape== "no":
            print("""
Well....that's very noble....but unfortunately Faceless Men caught you and killed""")
            FAIL()
    #you decided to stay commited to faceless men forewer           
    elif final== "b":      
        print("""
You decided to reject your identity as Arya Stark. 
Now, you will be one of them and will serve the House of Black and White forever.
This is the end of the game, thank you!""")
        exit(0)
            
INTRO() # START THE GAME
# Out:
# ********************************************************************************
